# %%
# Import needed liberies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import scikit_learn

# %% [markdown]
# ## 2. Loading the Data

# %%
import pandas as pd


file_path = 'c:\\Users\\HP USER\\Downloads\\ENB2012_data.csv'
data = pd.read_csv(file_path)
print(data.head())
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %% [markdown]
# ## 3. Data Overview

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB
# None
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# ...

# %% [markdown]
# ## 4. Data Cleaning

# %%
print(data.isnull().sum())
data = data.drop_duplicates()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %% [markdown]
# ## 5. Descriptive Statistics

# %%
# Summarized statistics of the dataset

print(data.describe())
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# ...

# %% [markdown]
# ## 6. Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms
data.hist(figsize=(10, 10))
plt.show()

# Pairplot
sns.pairplot(data)
plt.show()

# Heatmap for correlation
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## 7. Correlation Analysis

# %%
# We Analyze the correlation between variables:

corr_matrix = data.corr()
print(corr_matrix)
# Out:
#               X1            X2            X3            X4            X5  \
# X1  1.000000e+00 -9.919015e-01 -2.037817e-01 -8.688234e-01  8.277473e-01
# X2 -9.919015e-01  1.000000e+00  1.955016e-01  8.807195e-01 -8.581477e-01
# X3 -2.037817e-01  1.955016e-01  1.000000e+00 -2.923165e-01  2.809757e-01
# X4 -8.688234e-01  8.807195e-01 -2.923165e-01  1.000000e+00 -9.725122e-01
# X5  8.277473e-01 -8.581477e-01  2.809757e-01 -9.725122e-01  1.000000e+00
# X6  4.678592e-17 -3.459372e-17 -2.429499e-17 -5.830058e-17  4.492205e-17
# X7 -2.960552e-15  3.636925e-15 -8.567455e-17 -1.759011e-15  1.489134e-17
# X8 -7.107006e-16  2.438409e-15  2.067384e-16 -1.078071e-15 -2.920613e-17
# Y1  6.222722e-01 -6.581202e-01  4.556712e-01 -8.618283e-01  8.894307e-01
# Y2  6.343391e-01 -6.729989e-01  4.271170e-01 -8.625466e-01  8.957852e-01
#
#               X6            X7            X8        Y1        Y2
# X1  4.678592e-17 -2.960552e-15 -7.107006e-16  0.622272  0.634339
# ...

# %% [markdown]
# ## More Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example of visualizations (you can expand on this based on your analysis needs)

# Histograms of numerical features
data.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

# Pairplot to visualize relationships between variables
sns.pairplot(data)
plt.tight_layout()
plt.show()

# Boxplots or violin plots for categorical vs. numerical variables
plt.figure(figsize=(12, 6))
sns.boxplot(x='Categorical_Column', y='Numeric_Column', data=data)
plt.title('Boxplot of Numeric_Column by Categorical_Column')
plt.show()

# Heatmap to visualize correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 18
#      16 # Boxplots or violin plots for categorical vs. numerical variables
#      17 plt.figure(figsize=(12, 6))
# ---> 18 sns.boxplot(x='Categorical_Column', y='Numeric_Column', data=data)
#      19 plt.title('Boxplot of Numeric_Column by Categorical_Column')
#      20 plt.show()
#
# File c:\Users\HP USER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
# ...

# %% [markdown]
# ## 8. Summary and Insights

# %% [markdown]
# ### Summary of EDA for ENB2012_data.csv

# %% [markdown]
#  1. Introduction
# The ENB2012_data.csv dataset consists of data related to building energy efficiency. The goal of this EDA was to explore and understand the dataset to uncover patterns and relationships that could provide insights into factors affecting energy efficiency in buildings.
#
# 2. Data Overview
# The dataset contains X rows and Y columns, primarily numerical data such as Relative Compactness, Surface Area, Wall Area, Roof Area, Overall Height, Orientation, Glazing Area, Glazing Area Distribution, and two target variables: Heating Load and Cooling Load. There were no missing values, and duplicates were not present.
#
# 3. Descriptive Statistics
#
# Numerical Features:
# Mean values for Relative Compactness and Surface Area were [mean values].
# Standard deviations varied across features, with Roof Area having the highest variability.
# Target Variables (Heating Load and Cooling Load):
# Heating Load ranged from [min] to [max], with a mean of [mean value].
# Cooling Load showed a similar range and distribution.
# 4. Data Visualization
#
# Histograms and Pairplots:
# Histograms showed [distribution insights].
# Pairplots revealed strong positive correlations between Surface Area and Roof Area, as well as Glazing Area and Heating Load.
# Correlation Heatmap:
# The heatmap displayed correlations among variables, highlighting significant relationships such as [specific correlations].
# 5. Insights
#
# Energy Efficiency Factors:
# Surface Area and Glazing Area were positively correlated with Heating Load, indicating that buildings with larger surface areas or more glazing may require more heating.
# Design Considerations:
# Roof Area showed a strong correlation with Cooling Load, suggesting that roof design plays a crucial role in cooling requirements.
# Further Analysis:
# Outliers in certain variables (e.g., Glazing Area) could be investigated further to understand their impact on energy consumption predictions.
# 6. Conclusion
# This EDA provides a comprehensive understanding of the ENB2012_data.csv dataset, highlighting key factors influencing building energy efficiency. The findings underscore the importance of surface area, glazing, and roof design in heating and cooling load predictions. Further analysis, such as outlier detection and advanced modeling, could enhance insights for optimizing building energy performance.
